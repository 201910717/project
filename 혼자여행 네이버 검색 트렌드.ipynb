# %%
import os
import sys
import urllib.request
import json
client_id = "cVylRRDS1gmWS_KnKiFK"
client_secret = "aXpo6A2Blc"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2020-12-01\",\"endDate\":\"2022-12-31\",\"timeUnit\":\"month\",\"keywordGroups\":[{\"groupName\":\"혼자여행\",\"keywords\":[\"국내혼자여행\",\"혼자여행\"]}]}"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    a = response_body.decode('utf-8')
    b= json.loads(a)
else:
    print("Error Code:" + rescode)

# %%
date=[]  ##날짜 리스트
stravel= [] ##혼자여행 검색량

for i in b['results'][0]['data']:
    date.append(i['period'])
    stravel.append(i['ratio'])
    
df = pd.DataFrame([date,stravel]).T  # 이후 행과 열 변경을 위한 T
df.columns=['날짜','혼자여행']

# %%
df
# Out:
#             날짜      혼자여행
# 0   2020-12-01  21.71457
# 1   2021-01-01  24.68645
# 2   2021-02-01   33.7462
# 3   2021-03-01  35.27693
# 4   2021-04-01  38.64999
# 5   2021-05-01  41.45438
# 6   2021-06-01  51.75274
# 7   2021-07-01  55.18423
# 8   2021-08-01  72.35335
# 9   2021-09-01  56.76559
# 10  2021-10-01   59.4843
# 11  2021-11-01  54.09363
# 12  2021-12-01  55.54257
# 13  2022-01-01  60.53205
# 14  2022-02-01  47.69416
# 15  2022-03-01  47.48773
# 16  2022-04-01  54.61945
# 17  2022-05-01  67.17301
# 18  2022-06-01  65.89545
# 19  2022-07-01   85.5301
# 20  2022-08-01   89.1135
# 21  2022-09-01  62.04331
# 22  2022-10-01       100
# 23  2022-11-01  87.84373
# 24  2022-12-01  83.29048

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'

plt.rcParams['font.size']=12

plt.figure(figsize=(30,12))


plt.plot(df['날짜'],df['혼자여행'])

for i in range(len(df)):
    plt.text(i,df['혼자여행'][i],df['혼자여행'][i], fontsize=10, horizontalalignment = 'center', verticalalignment = 'bottom')

plt.legend(['혼자여행'], loc='upper left')

# %%
client_id = "cVylRRDS1gmWS_KnKiFK"
client_secret = "aXpo6A2Blc"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2019-10-01\",\"endDate\":\"2022-12-31\",\"timeUnit\":\"month\",\"keywordGroups\":[{\"groupName\":\"부산여행\",\"keywords\":[\"부산혼자여행\",\"부산혼자숙소\"]}]}"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    a = response_body.decode('utf-8')
    b= json.loads(a)
else:
    print("Error Code:" + rescode)

# %%
date=[]  ##날짜 리스트
stravel= [] ##혼자여행 검색량

for i in b['results'][0]['data']:
    date.append(i['period'])
    stravel.append(i['ratio'])
    
df = pd.DataFrame([date,stravel]).T  # 이후 행과 열 변경을 위한 T
df.columns=['날짜','부산혼자여행']

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'

plt.rcParams['font.size']=12

plt.figure(figsize=(30,12))


plt.plot(df['날짜'],df['부산혼자여행'])

for i in range(len(df)):
    plt.text(i,df['부산혼자여행'][i],df['부산혼자여행'][i], fontsize=10, horizontalalignment = 'center', verticalalignment = 'bottom')

plt.legend(['부산혼자여행'], loc='upper left')
